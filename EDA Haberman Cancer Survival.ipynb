# %% [markdown]
# # Exploratory Data analysis of Haberman Cancer Survival
# **Download Haberman Cancer Survival dataset from Kaggle.**
#
# (https://www.kaggle.com/gilsousa/habermans-survival-data-set)

# %%
#Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings. filterwarnings("ignore")

# %%
#Reading Dataset
df=pd.read_csv('haberman.csv',names=["age","operation_Year","axil_nodes","survival_status"])
df.head()
# Out:
#    age  operation_Year  axil_nodes  survival_status
# 0   30              64           1                1
# 1   30              62           3                1
# 2   30              65           0                1
# 3   31              59           2                1
# 4   31              65           4                1

# %%
df.shape
# Out:
# (306, 4)

# %% [markdown]
# In our dataset
#
# **Number of Rows**- 306
#
# **Number of columns**- 4
#
# **Feature or Independent variable**- age,operation_Year,axil_nodes
#
# **Dependent variable or output label**- survival_status

# %%
# column names in our dataset
print (df.columns)
# Out:
# Index(['age', 'operation_Year', 'axil_nodes', 'survival_status'], dtype='object')

# %% [markdown]
# <h3>Data points per class</h3>

# %%
df["survival_status"].value_counts()
# Out:
# 1    225
# 2     81
# Name: survival_status, dtype: int64

# %% [markdown]
#
#  <h3> Data points per class Graphical representation using counter plot</h3>

# %%
sns.set_style('whitegrid')
sns.countplot(x='survival_status',data=df)
# Out:
# <AxesSubplot:xlabel='survival_status', ylabel='count'>

# %% [markdown]
# # Objective
#
# **The objective for a problem is that on the basis of Feature or Independent variable- age,operation_Year,axil_nodes
# we have to predict that Dependent variable or output label- survival_status**
#
# Survival status (class attribute)
#
# 1 = the patient survived 5 years or longer
#
# 2 = the patient died within 5 year

# %% [markdown]
# <h4>Checking for NULL values</h4>

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# So by plotting the heatmap we can clearly see there is no missing value in our dataset

# %% [markdown]
# ### Performing Univariate analysis - Plot PDF, CDF, Boxplot, Voilin plots

# %%
#sns.kdeplot(data=df, x="age", hue="survival_status")
sns.FacetGrid(df, hue="survival_status", size=5) \
   .map(sns.distplot, "age") \
   .add_legend();
plt.show();

# %% [markdown]
# <h3>Observation</h3>
#
# 1.This forms a large amount of overlapping area
# when we plot histogram of age
#
# 2.Commenting within the range 34 to 75 is difficult as a lot of overlapping.
#
# 3.People having age less than 34 survived 5 years or longer
#
# 4.People having age greater than 75 died within 5 year

# %%
sns.ecdfplot(data=df, x="age", hue="survival_status")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Proportion'>

# %% [markdown]
# **Cumulative distribution plot**
#
# 1.Shows that the proportion approximately remain the same
#
# 2.95% of the people under survival_status 1 and survival_status 2 have age < 70

# %%
ax = sns.boxplot(x="survival_status", y="age", data=df)

# %% [markdown]
# **Box plot**
#
# 1.Shows there is a lot of overlapping
#
# 2.The box plot show the 50 th percentile of both survived states approximately near to 53 years
#
# 3.Shows the presence of no outliers

# %%
sns.violinplot(x="survival_status", y="age", data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='survival_status', ylabel='age'>

# %% [markdown]
# **Violin plot**
#
# 1.Combine the result of pdf and the box plot
#
# 2.Shows there is a lot of overlapping

# %%
#sns.kdeplot(data=df, x="operation_Year", hue="survival_status")
sns.FacetGrid(df, hue="survival_status", size=5) \
   .map(sns.distplot, "operation_Year") \
   .add_legend();
plt.show();

# %% [markdown]
# <h3>Observation</h3>
#
# 1.This forms a large amount of overlapping area
# when we plot histogram of operation year
#
# 2.Commenting is difficult as a lot of overlapping.

# %%
sns.ecdfplot(data=df, x="operation_Year", hue="survival_status")
# Out:
# <AxesSubplot:xlabel='operation_Year', ylabel='Proportion'>

# %% [markdown]
# **Cumulative distribution plot**
#
# 1.90% to 95% of the people under survival_status 1 and survival_status 2 have operation_Year < 68

# %%
ax = sns.boxplot(x="survival_status", y="operation_Year", data=df)

# %% [markdown]
# **Box plot**
#
#
# 1.Shows there is a lot of overlapping
#
# 2.The box plot show the 50 th percentile of both survived states approximately near to 63 years
#
# 3.Shows the presence of no outliers

# %%
sns.violinplot(x="survival_status", y="operation_Year", data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='survival_status', ylabel='operation_Year'>

# %% [markdown]
# **Violin plot**
#
# 1.Combine the result of pdf and the box plot
#
# 2.shows there is a lot of overlapping

# %%
#sns.kdeplot(data=df, x="axil_nodes", hue="survival_status")
sns.FacetGrid(df, hue="survival_status", size=5) \
   .map(sns.distplot, "axil_nodes") \
   .add_legend();
plt.show();

# %% [markdown]
# <h3>Observation</h3>
#
# 1.This forms a large amount of overlapping area
# when we plot histogram of axil nodes
#
# 2.We can comment that when axil nodes nearly 0 the density of people survived more than 5 years is more.
#
# 3.But from 5 axil node the pdf of survival state 2 is more means more pobability of that person died within 5 years

# %%
sns.ecdfplot(data=df, x="axil_nodes", hue="survival_status")
# Out:
# <AxesSubplot:xlabel='axil_nodes', ylabel='Proportion'>

# %% [markdown]
# **Cumulative distribution plot**
#
#
# 1.80% of the people under survival_status 1 have axil_nodes less than or equal to 5.
#
# 2.80% of the people under survival_status 2 have axil_nodes less than 14.

# %%
ax = sns.boxplot(x="survival_status", y="axil_nodes", data=df)

# %% [markdown]
# **Box plot**
#
#
# 1.Shows the presence of outliers in survived state 1 and few in survived state 2.
#
# 2.75th percentile of survived people have axial_nodes less than 5
#
# 3.50th percentile of survived people not more than 5 years have axial_nodes less than 5

# %%
sns.violinplot(x="survival_status", y="axil_nodes", data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='survival_status', ylabel='axil_nodes'>

# %% [markdown]
# **Violin plot**
#
# 1.Combine the result of pdf and the box plot
#
#  2.Most of the Patient survived have axil_node nearly one

# %% [markdown]
# ###  Performing Bivariate analysis - Plot 2D Scatter plots and Pair plots

# %% [markdown]
# <h2>Pair plot</h2>

# %%
sns.pairplot(df,hue='survival_status')

# %% [markdown]
# <h3>Observations</h3>
#
# 1. The survival_status is very difficult to find with the help of these three independent features age,operation_Year,axil_nodes.
#
# 2. As by plotting garphs between them in all the cases there is a lot of overlapping between them.
#
# 3. Age and axil_nodes are the most useful features to identify survival_status from others but it also contains a lot of overlapping.

# %% [markdown]
# <h2> 2D Scatter plots</h2>

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival_status", height=4) \
   .map(plt.scatter, "age", "operation_Year") \
   .add_legend();
plt.show();

# %% [markdown]
# <h3>Observation</h3>
#
# 1.This forms a large amount of overlapping area
# when we plot scatterplot of operation_year and age
#
# 2.Commenting is difficult as a lot of overlapping.

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival_status", height=4) \
   .map(plt.scatter, "axil_nodes", "operation_Year") \
   .add_legend();
plt.show();

# %% [markdown]
# <h3>Observation</h3>
#
# 1.This forms a large amount of overlapping area
# when we plot scatterplot of year and axial_nodes
#
# 2.Commenting is difficult as a lot of overlapping.

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival_status", height=4) \
   .map(plt.scatter, "axil_nodes", "age") \
   .add_legend();
plt.show();

# %% [markdown]
# <h3>Observation</h3>
#
# 1.This forms a large amount of overlapping area
# when we plot scatter plot of operation age and axial_nodes.
#
# 2.Commenting is difficult as a lot of overlapping.

# %% [markdown]
# <h2>Final Conclusions</h2>
#
# 1. The survival_status is very difficult to find with the help of these three independent features age, operation_Year, axil_nodes.
#
# 2. As by plotting garphs between them in all the cases there is a lot of overlapping between them 80% to 90%.
#
# 3. Age and axil_nodes is 25% more useful features to identify survival_status from others but it also contains a lot of overlapping.
#
# 4. Order of useful features axil_nodes > Operation_year > Age.
#
# 5. A non linear technique will be required to differentiate between the survival_status .
#
# 6. More useful features should be collected for the determination of survival_status.
